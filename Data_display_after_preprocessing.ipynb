# %%
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
import numpy as np
import cv2
# %matplotlib inline
dir_path='mpii_human_pose_v1\\output_images\\'

# %%
raw_datas= open('train_data\\new_data.json').readlines()
data=json.loads(raw_datas[9059].strip())

# %%
print(data['filename'])
img = cv2.imread(dir_path+data['filename'])
height, width, channels = img.shape 
joints_pos=data['joint_pos']
for joint in joints_pos:
    x=int(joints_pos[str(joint)][0])
    y=int(joints_pos[str(joint)][1])
    cv2.circle(img,(x,y), 8, (0,0,255), -1)
side=data['scale']*200*1.1
left_top_X=int(data['objpos'][0]-(side/2))
left_top_Y=int(data['objpos'][1]-(side/2))
right_down_X=min(width,left_top_X+int(side))
right_down_Y=min(height,left_top_Y+int(side))
left_top_X=max(0,left_top_X)
left_top_Y=max(0,left_top_Y)
cv2.rectangle(img,(left_top_X,left_top_Y),(right_down_X,right_down_Y),(0,255,255),5)
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 9059-062429040.jpg
