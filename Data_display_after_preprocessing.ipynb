# %%
import json
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
import cv2
# %matplotlib inline
dir_path='mpii_human_pose_v1\\output_images360x480\\'

# %%
raw_datas= open('train_data\\new_data.json').readlines()
data=json.loads(raw_datas[110].strip())
width=360
height=480

# %%
print(data['filename'])
img = cv2.imread(dir_path+data['filename'])
joints_pos=data['joint_pos']
for joint in joints_pos:
    x=int(joints_pos[str(joint)][0])
    y=int(joints_pos[str(joint)][1])
    cv2.circle(img,(x,y), 8, (0,0,255), -1)
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 110-032320293.jpg
